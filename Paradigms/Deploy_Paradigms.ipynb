# %%
from oop_fisher import Strategy as strategy

# %%
tesla = strategy("TSLA",50)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(dir(tesla))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'absolute_price_oscillator', 'bollinger_bands', 'bot', 'data', 'macd', 'momentum', 'num_days', 'plot', 'relative_strenght_index', 'simple_moving_average', 'standard_deviation', 'symbol']

# %%
help(tesla)
# Out:
# Help on Strategy in module oop_fisher object:
#
# class Strategy(builtins.object)
#  |  Strategy(symbol, num_days)
#  |
#  |  Strategy is a class that gathers 6 technicals indicators
#  |  by providing the name of the stock and the quantity of
#  |  days to apply the indicator
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, symbol, num_days)
#  |      Common attributes
#  |      symbol: str = string of the stock to analyze
#  |      num_days: int = integer as quantity of days to apply
#  |
#  |  absolute_price_oscillator(self, short, long)
#  |      Differences between short-term & long-term
#  |      moving averages to current price,
#  |      Choose short & long period days
#  |
#  |  bollinger_bands(self, stdev_factor)
#  |      Choose number of factors for stdev to apply
#  |
#  |  macd(self, short, long)
#  |      Moving Average Convergence Divergence.
#  |      Provide Integers for Short & Long Oscillators
#  |
#  |  momentum(self)
# ...

# %%
tesla.bot
# Out:
#                   TSLA
# Date
# 2022-03-25  336.880005
# 2022-03-28  363.946655
# 2022-03-29  366.523346
# 2022-03-30  364.663330
# 2022-03-31  359.200012
# ...                ...
# 2023-03-20  183.250000
# 2023-03-21  197.580002
# 2023-03-22  191.149994
# 2023-03-23  192.220001
# 2023-03-24  190.410004
#
# [251 rows x 1 columns]

# %%
tesla.simple_moving_average()
# Out:
#                   TSLA      SMA 50
# Date
# 2022-03-25  336.880005  336.880005
# 2022-03-28  363.946655  350.413330
# 2022-03-29  366.523346  355.783335
# 2022-03-30  364.663330  358.003334
# 2022-03-31  359.200012  358.242670
# ...                ...         ...
# 2023-03-20  183.250000  174.692200
# 2023-03-21  197.580002  176.382600
# 2023-03-22  191.149994  177.810200
# 2023-03-23  192.220001  179.277600
# 2023-03-24  190.410004  180.621400
#
# [251 rows x 2 columns]

# %%
tesla.plot()

# %%
amd = strategy("AMD",30)

amd.simple_moving_average()

amd.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Funcional. Todo es Funciones

# %%
import functional_fisher as functional

# %%
btc = functional.SimpleMovingAverage("BTC-USD",50)
eth = functional.MovingAverageConvergenceDivergence("ETH-USD",25,75)
ada = functional.StandardDeviation("ADA-USD",2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
btc,eth,ada
# Out:
# (                 BTC-USD         SMA50
#  Date
#  2022-03-27  46820.492188  46820.492188
#  2022-03-28  47128.003906  46974.248047
#  2022-03-29  47465.730469  47138.075521
#  2022-03-30  47062.664062  47119.222656
#  2022-03-31  45538.675781  46803.113281
#  ...                  ...           ...
#  2023-03-23  28333.972656  23703.528516
#  2023-03-24  27493.285156  23783.956797
#  2023-03-25  27494.707031  23864.864492
#  2023-03-26  27994.330078  23958.114141
#  2023-03-27  27890.101562  24056.802852
#
#  [366 rows x 2 columns],
#                  ETH-USD  MACD ETH-USD
#  Date
#  2022-03-27  3291.577637      0.000000
#  2022-03-28  3336.634521      0.000000
#  2022-03-29  3401.987793      0.000000
#  2022-03-30  3385.157959      0.000000
#  2022-03-31  3281.642822      0.000000
#  ...                 ...           ...
#  2023-03-23  1816.405151     39.526268
#  2023-03-24  1752.044800     38.039199
#  2023-03-25  1743.764771     37.924307
#  2023-03-26  1775.676758     36.559486
# ...

# %%
functional.plot(eth)

# %% [markdown]
# # Procedural o Control Remoto int main() de C

# %%
from procedural_fisher import *

# %%
commands(functions)
# Out:
# Procedural Programming Approach
#
# or Imperative, we set a remote control
#
# and we dictate how to execute the program
#
# 0 : absolute_price_oscillator()
# 1 : bollinger_bands()
# 2 : macd()
# 3 : momentum()
# 4 : plot()
# 5 : simple_moving_average()
# 6 : standard_deviation()
#
# SELECT ONE INDICATOR TO PLOT
#
#
# >>>	0
#
# What Stock you want to Analyze?
#
# =>	ENPH
#
# Number of Days to use in the indicator?
#
# =>	25
# [*********************100%***********************]  1 of 1 completed
#
# short..	25
#
# long..	78
# PRESS [ENTER] in order to continue
#
# Procedural Programming Approach
#
# or Imperative, we set a remote control
#
# and we dictate how to execute the program
#
# 0 : absolute_price_oscillator()
# 1 : bollinger_bands()
# 2 : macd()
# 3 : momentum()
# 4 : plot()
# 5 : simple_moving_average()
# 6 : standard_deviation()

# %%
# SE LLAMARA RECURSIVAMENTE HASTA QUE CORTEMOS
